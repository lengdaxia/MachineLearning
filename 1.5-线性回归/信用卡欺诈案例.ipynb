# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
path = 'data' + os.sep + 'creditcard.csv'
print(path)
data = pd.read_csv(path)
data.head()
# Out:
# data/creditcard.csv
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
cout_class = pd.value_counts(data['Class'],sort=True).sort_index()
cout_class.plot(kind='bar')
plt.title('Fraud class histogram')
plt.xlabel('Class')
plt.ylabel('Frequency')

print(type(cout_class))
print(cout_class)
# Out:
# <class 'pandas.core.series.Series'>
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# 数据预处理
from sklearn.preprocessing import StandardScaler

data['normAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1,1))
data.drop(['Time','Amount'], axis=1)
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9     ...           V22       V23       V24       V25  \
# 0  0.098698  0.363787     ...      0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425     ...     -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654     ...      0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024     ...      0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739     ...      0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# 下采样
X = data.loc[:,data.columns != 'Class']
y = data.loc[:,data.columns == 'Class']

number_records_fraud = len(data[data.Class == 1])
fraud_indices = np.array(data[data.Class == 1].index)

normal_indices = data[data.Class == 0].index

print(number_records_fraud)

# 关键步骤，对正常数据的索引进行采样，采样数量为 欺诈数据的数量
random_normal_indices = np.random.choice(normal_indices,number_records_fraud,replace=False)
random_normal_indices = np.array(random_normal_indices)

under_sample_indices = np.concatenate([fraud_indices,random_normal_indices])
under_sample_data = data.iloc[under_sample_indices,:]

X_undersample = under_sample_data.loc[:,under_sample_data.columns !='Class']
y_undersample = under_sample_data.loc[:,under_sample_data.columns == 'Class']

print('Percent of normal transactions',len(under_sample_data[under_sample_data.Class == 0])/len(under_sample_data))
print('Percent of fraud transactions', len(under_sample_data[under_sample_data.Class == 1])/len(under_sample_data))
print('Undersample data size:',len(under_sample_data))
# Out:
# 492
# Percent of normal transactions 0.5
# Percent of fraud transactions 0.5
# Undersample data size: 984

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)
print('number of train dataset transactions :',len(X_train))
print('number of test dataset transactions:', len(X_test))
print('Number ot Total trancastions:', len(X_train) + len(X_test))

print('*' * 20)

X_train_uundersample, X_test_undersample, y_train_undersample, y_test_undersample = train_test_split(X_undersample, y_undersample,test_size=0.3,random_state=42)
print('undersample of train X size:',len(X_train_uundersample))
print('Undersample of test X size:', len(X_test_undersample))
print('Total undersample dataset size:',len(X_train_uundersample) + len(X_test_undersample))
# Out:
# number of train dataset transactions : 199364
# number of test dataset transactions: 85443
# Number ot Total trancastions: 284807
# ********************
# undersample of train X size: 688
# Undersample of test X size: 296
# Total undersample dataset size: 984

# %%
# 查全率
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold,cross_val_score
from sklearn.metrics import confusion_matrix, recall_score, classification_report

# %%
def print_Kfold_scores(x_train_data, y_tran_data):
    
    fold = KFold(len(y_tran_data),5,shuffle=False)
    
    c_param_range = [0.01,0.1,1,10,100]
    
    results_table = pd.DataFrame(index=range(len(c_param_range),2),columns=['C_parameters','Mean recall score'])
    results_table['C_parameters'] = c_param_range
    
    j = 0
    for c_param in c_param_range:
        print('-----------------------------')
        print('C parameter :', c_param)
        print('-----------------------------')
        
        recall_accs = []
        for ierration, indices in enumerate(fold, start=1):
            
            lr = LogisticRegression(C = c_param, penalty='l1')

            lr.fit(x_train_data.iloc[indices[0],:],y_tran_data.iloc[indices[0],:].values.ravel())
            
            y_pred_undersample = lr.predict(x_train_data.iloc[indices[1],:].values)
            
            recall_acc = recall_score(y_train_data.iloc[indices[1],:].values,y_pred_undersample)
            
            recall_accs.append(recall_acc)
        
        results_table.loc[j,'Mean recall score'] = np.mean(recall_accs)
        j += 1
        
        print('')
        print('Mean recall score', np.mean(recall_accs))
        print('')
    
    best_c = results_table.loc[results_table['Mean recall socre'].idxmax()]['C_parameter']
    
    print('*'*20)
    print('Best model to choose from cross validation is with c Paramsyer = ', best_c)
    print('*'*20)
    return c

# %%
bset_c = print_Kfold_scores(X_train_uundersample,y_train_undersample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-ea31c4c83bbd> in <module>()
# ----> 1 bset_c = print_Kfold_scores(X_train_uundersample,y_train_undersample)
#
# <ipython-input-29-272e10c791ed> in print_Kfold_scores(x_train_data, y_tran_data)
#       1 def print_Kfold_scores(x_train_data, y_tran_data):
# ----> 2     fold = KFold(len(y_tran_data),5,shuffle=False)
#       3
#       4     c_param_range = [0.01,0.1,1,10,100]
#       5
#
# TypeError: __init__() got multiple values for argument 'shuffle'
